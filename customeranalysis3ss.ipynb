# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

mca = pd.read_csv('/Users/spicasumampouw/IronSpica/lab/lab-customer-analysis-round-3/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
pd.set_option('display.max_columns', None) # displays all columns in dfs

import warnings
warnings.filterwarnings('ignore') # no more 'useless' red warnings

# %%
#Show DataFrame info.

#mca.head()
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
#Describe DataFrame.

mca.head()
#mca.describe()#.T
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
#mca['Response'] = pd.to_numeric(mca['Response'], errors='coerce')
mca.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
#Show a plot of the total number of responses.

#mca['Response'].value_counts()#[:20]
#mca['Response'].value_counts().plot(kind='barh')
sns.countplot(x='Response', data=mca)
plt.title('Total Response')

# %%
plt.figure(figsize=(16,8))
#plt.hist(mca['Response'])
#plt.scatter(mca['Response'], mca['Sales Channel'])
sns.barplot(x='Total Claim Amount ', y='Response', data=mca)

#sns.barplot(x="state", y="median_home_val", data=data1)
#plt.scatter(data['ic2'], data['ic3'])
plt.show()

# %%
fig, axs = plt.subplots(2, 2)

axs[0, 0].hist(mca['Response'])
axs[0, 1].hist(mca['Sales Channel'])
axs[1, 0].hist(mca['Total Claim Amount'])
axs[1, 1].hist(mca['Income'])

'''Show a plot of the response rate by the sales channel.
Show a plot of the response rate by the total claim amount.
Show a plot of the response rate by income.'''
# Out:
# (array([2317.,  522., 1381.,  893.,  749.,  791.,  759.,  698.,  545.,
#          479.]),
#  array([    0. ,  9998.1, 19996.2, 29994.3, 39992.4, 49990.5, 59988.6,
#         69986.7, 79984.8, 89982.9, 99981. ]),
#  <BarContainer object of 10 artists>)

# %%
#sns.histplot(x = 'Sales Channel', hue = 'Response', multiple = 'fill', data = mca)
plt.pie(mca['Response'].value_counts(), autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc6cdf92ac0>,
# ...
#  [Text(-0.9905492504207868, 0.4783431639428096, ''),
#   Text(0.9905492504207868, -0.47834316394280973, '')],
#  [Text(-0.5402995911386109, 0.2609144530597143, '86%'),
#   Text(0.5402995911386109, -0.2609144530597144, '14%')])
